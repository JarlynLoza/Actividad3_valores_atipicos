# %% [markdown]
# <a href="https://colab.research.google.com/github/JarlynLoza/Actividad3_valores_atipicos/blob/main/Actividad3_2_ValoresAtipicosporDataframe21.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importar librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga de un archivo .xlsx desde un libro con varias páginas
df_2021=pd.read_excel('Gastos y costos 20-23.xlsx', sheet_name='2021')
df_2021
# Out:
#      CALOR Y CONTROL S.A DE C.V              Unnamed: 1  \
# 0              DEDUCCIONES 2021                     NaN
# 1                           NaN                     NaN
# 2                         FECHA                   FOLIO
# 3           2021-01-01 00:00:00  0001010100750847116902
# 4           2021-01-01 00:00:00  0001010100752163714102
# ...                         ...                     ...
# 3033        2021-12-01 00:00:00                  127043
# 3034        2021-12-01 00:00:00                   11740
# 3035        2021-12-01 00:00:00              1092957089
# 3036        2021-12-01 00:00:00                  747826
# 3037        2021-12-01 00:00:00                 1227374
#
#                                 Unnamed: 2    Unnamed: 3  \
# 0                                      NaN           NaN
# 1                                      NaN           NaN
# 2                                     UUID           RFC
# 3     71B4C8B9-8DAA-47CC-AD47-9DD90AA5AF6B  BNM840515VB1
# ...

# %%
df_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3038 entries, 0 to 3037
# Data columns (total 18 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   CALOR Y CONTROL S.A DE C.V  3037 non-null   object
#  1   Unnamed: 1                  2889 non-null   object
#  2   Unnamed: 2                  3036 non-null   object
#  3   Unnamed: 3                  3036 non-null   object
#  4   Unnamed: 4                  3036 non-null   object
#  5   Unnamed: 5                  3036 non-null   object
#  6   Unnamed: 6                  3036 non-null   object
#  7   Unnamed: 7                  2382 non-null   object
#  8   Unnamed: 8                  3036 non-null   object
#  9   Unnamed: 9                  3036 non-null   object
#  10  Unnamed: 10                 3036 non-null   object
#  11  Unnamed: 11                 3036 non-null   object
#  12  Unnamed: 12                 3036 non-null   object
# ...

# %%
df_2021 =pd.read_excel ('Gastos y costos 20-23.xlsx', sheet_name= '2020', skiprows= 5)
df_2021
# Out:
#           FECHA                   FOLIO                                  UUID  \
# 0    2020-01-01                   39408  BD20F436-72CC-4BE2-AD37-5999D71AA391
# 1    2020-01-01  0001010100750847116902  85AEAC2E-6395-44A0-9CB9-754D06893375
# 2    2020-01-01  0001010100752163714102  BD0DFE85-D776-41CB-9C5C-4FA7923E687A
# 3    2020-01-01                    3663  EF4504D6-830D-415C-AF03-80CF54C5E28E
# 4    2020-01-01                    2849  EC2F4AA4-BA64-4E2E-A5B7-4EBBE042D6D3
# ...         ...                     ...                                   ...
# 3337 2020-12-01                  125834  80BCB1D8-673F-495B-9C2A-4AC9F9CB38E5
# 3338 2020-12-01                   37652  D4C7C1FB-03A7-4046-A2BD-03EBE7DA861E
# 3339 2020-12-01                     160  FFCEE7D4-1F38-4D44-BE02-EB042DAACEE7
# 3340 2020-12-01                  634875  8DFF4F01-2F8B-4085-B116-05A314108B02
# 3341 2020-12-01                 1044477  F18225D6-4024-4F03-A15A-D18917386D59
#
# ...

# %%
df_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3342 entries, 0 to 3341
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   FECHA        3342 non-null   datetime64[ns]
#  1   FOLIO        3153 non-null   object
#  2   UUID         3342 non-null   object
#  3   RFC          3342 non-null   object
#  4   PROVEEDOR    3342 non-null   object
#  5   TIPO GASTO   3342 non-null   object
#  6   GASTO        840 non-null    object
#  7   DESCRIPCION  3342 non-null   object
#  8   TC           2951 non-null   float64
#  9   IMPORTE      3308 non-null   float64
#  10  IVA          3074 non-null   float64
#  11  RET ISR      3342 non-null   float64
#  12  RET IVA      3342 non-null   float64
#  13  TOTAL MX     3342 non-null   float64
#  14  TOTAL SAT    3342 non-null   float64
#  15  TIPO         3341 non-null   object
#  16  STATUS       3342 non-null   object
#  17  POLIZA       21 non-null     object
# ...

# %%
#Corroboramos valores nulos
valores_nulos=df_2021.isnull().sum()
valores_nulos
# Out:
# FECHA             0
# FOLIO           189
# UUID              0
# RFC               0
# PROVEEDOR         0
# TIPO GASTO        0
# GASTO          2502
# DESCRIPCION       0
# TC              391
# IMPORTE          34
# IVA             268
# RET ISR           0
# RET IVA           0
# TOTAL MX          0
# TOTAL SAT         0
# TIPO              1
# STATUS            0
# POLIZA         3321
# Columna1          0
# dtype: int64

# %%
#Reemplazamos valores nulos del dataframe con bfill
data21=df_2021.fillna(method="bfill")
data21
# Out:
#           FECHA                   FOLIO                                  UUID  \
# 0    2020-01-01                   39408  BD20F436-72CC-4BE2-AD37-5999D71AA391
# 1    2020-01-01  0001010100750847116902  85AEAC2E-6395-44A0-9CB9-754D06893375
# 2    2020-01-01  0001010100752163714102  BD0DFE85-D776-41CB-9C5C-4FA7923E687A
# 3    2020-01-01                    3663  EF4504D6-830D-415C-AF03-80CF54C5E28E
# 4    2020-01-01                    2849  EC2F4AA4-BA64-4E2E-A5B7-4EBBE042D6D3
# ...         ...                     ...                                   ...
# 3337 2020-12-01                  125834  80BCB1D8-673F-495B-9C2A-4AC9F9CB38E5
# 3338 2020-12-01                   37652  D4C7C1FB-03A7-4046-A2BD-03EBE7DA861E
# 3339 2020-12-01                     160  FFCEE7D4-1F38-4D44-BE02-EB042DAACEE7
# 3340 2020-12-01                  634875  8DFF4F01-2F8B-4085-B116-05A314108B02
# 3341 2020-12-01                 1044477  F18225D6-4024-4F03-A15A-D18917386D59
#
# ...

# %%
#Corroboramos valores nulos
valores_nulos=data21.isnull().sum()
valores_nulos
# Out:
# FECHA             0
# FOLIO             0
# UUID              0
# RFC               0
# PROVEEDOR         0
# TIPO GASTO        0
# GASTO             0
# DESCRIPCION       0
# TC                0
# IMPORTE           0
# IVA               0
# RET ISR           0
# RET IVA           0
# TOTAL MX          0
# TOTAL SAT         0
# TIPO              0
# STATUS            0
# POLIZA         2898
# Columna1          0
# dtype: int64

# %%
# Sustituir valores nulos por valores no nulos hacia adelante "forward fill" (ffill)
#Filtro por columnas
data21["POLIZA"]=data21["POLIZA"].fillna(method="ffill")

# %%
#Corroboramos valores nulos
valores_nulos=data21.isnull().sum()
valores_nulos
# Out:
# FECHA          0
# FOLIO          0
# UUID           0
# RFC            0
# PROVEEDOR      0
# TIPO GASTO     0
# GASTO          0
# DESCRIPCION    0
# TC             0
# IMPORTE        0
# IVA            0
# RET ISR        0
# RET IVA        0
# TOTAL MX       0
# TOTAL SAT      0
# TIPO           0
# STATUS         0
# POLIZA         0
# Columna1       0
# dtype: int64

# %%
#filtro por columnas (cualitativas y cuantitativas)
cuanti=data21.iloc[:,[8,9,10,11,12,13,14,18]]
cuali=data21.iloc[:,[0,1,2,3,4,5,6,7,15,16,17]]

# %%
#Diagrama de caja o bigote de cada columna del dataframe
fig=plt.figure(figsize=(15,8))
cuanti.plot(kind='box', vert=False)
plt.title("Valores Atípicos del Dataframe")
plt.show() #Dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=cuanti

percentile25=y.quantile(0.25) #Q!
percentile75=y.quantile(0.75) #Q3
iqr= percentile75- percentile25

Limite_Superior_iqr=percentile75+1.5*iqr
Limite_Inferior_iqr=percentile25-1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido TC              1.00000
# IMPORTE      6976.21375
# IVA          1170.77250
# RET ISR         0.00000
# RET IVA         0.00000
# TOTAL MX     7983.17750
# TOTAL SAT    8269.28375
# Columna1        0.00000
# dtype: float64
# Limite inferior permitido TC              1.00000
# IMPORTE     -4160.35625
# IVA          -687.92750
# RET ISR         0.00000
# RET IVA         0.00000
# TOTAL MX    -4783.14250
# TOTAL SAT   -4832.96625
# Columna1        0.00000
# dtype: float64

# %%
#Encontramos los outliers
##Convertir outliers en nulos
outliers_iqr= cuanti[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#       TC   IMPORTE      IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT  Columna1
# 0    NaN       NaN  2248.28      NaN      NaN       NaN   16300.00  14051.72
# 1    NaN       NaN      NaN      NaN      NaN       NaN        NaN       NaN
# 2    NaN       NaN      NaN      NaN      NaN       NaN        NaN       NaN
# 3    NaN  10694.25  1711.08      NaN      NaN  12405.33   12405.33       NaN
# 4    NaN       NaN  5131.03      NaN      NaN       NaN        NaN       NaN
# ...   ..       ...      ...      ...      ...       ...        ...       ...
# 3337 NaN       NaN      NaN      NaN      NaN       NaN        NaN       NaN
# 3338 NaN       NaN      NaN      NaN      NaN       NaN        NaN       NaN
# 3339 NaN       NaN      NaN      NaN      NaN       NaN        NaN       NaN
# 3340 NaN       NaN      NaN      NaN      NaN       NaN        NaN       NaN
# 3341 NaN  14889.29      NaN      NaN      NaN  14889.29   14889.29       NaN
#
# [3342 rows x 8 columns]

# %%
#Obtenemos datos limpios del dataframe
cuanti_clean_iqr=cuanti[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
cuanti_clean_iqr
# Out:
#        TC  IMPORTE     IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT  Columna1
# 0     1.0     0.00     NaN      0.0      0.0   2248.28        NaN       NaN
# 1     1.0   490.00   78.40      0.0      0.0    568.40     568.40       0.0
# 2     1.0   195.00   31.20      0.0      0.0    226.20     226.20       0.0
# 3     1.0      NaN     NaN      0.0      0.0       NaN        NaN       0.0
# 4     1.0     0.00     NaN      0.0      0.0      0.00       0.00       0.0
# ...   ...      ...     ...      ...      ...       ...        ...       ...
# 3337  1.0   129.79   20.21      0.0      0.0    150.00     150.00       0.0
# 3338  1.0  2284.80  365.57      0.0      0.0   2650.37    2650.37       0.0
# 3339  1.0   163.79   26.21      0.0      0.0    190.00     190.00       0.0
# 3340  1.0     0.00    0.00      0.0      0.0      0.00       0.00       0.0
# 3341  1.0      NaN    0.00      0.0      0.0       NaN        NaN       0.0
#
# [3342 rows x 8 columns]

# %%
#Corroborar valores nulos
valores_nulos=cuanti_clean_iqr.isnull().sum()
valores_nulos
# Out:
# TC             9
# IMPORTE      424
# IVA          411
# RET ISR       45
# RET IVA      253
# TOTAL MX     420
# TOTAL SAT    426
# Columna1     240
# dtype: int64

# %%
#Se Reemplazan los valores atipicos (nulos) del dataframe con "mean"
#Realizamos una copia del dataframe
cuanti_clean_iqr1=cuanti.copy()
cuanti_clean_iqr1=cuanti_clean_iqr.fillna(round(cuanti.mean(),1))
cuanti_clean_iqr1
# Out:
#        TC  IMPORTE     IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT  Columna1
# 0     1.0     0.00  538.50      0.0      0.0   2248.28    3744.00     227.8
# 1     1.0   490.00   78.40      0.0      0.0    568.40     568.40       0.0
# 2     1.0   195.00   31.20      0.0      0.0    226.20     226.20       0.0
# 3     1.0  3141.70  538.50      0.0      0.0   3516.20    3744.00       0.0
# 4     1.0     0.00  538.50      0.0      0.0      0.00       0.00       0.0
# ...   ...      ...     ...      ...      ...       ...        ...       ...
# 3337  1.0   129.79   20.21      0.0      0.0    150.00     150.00       0.0
# 3338  1.0  2284.80  365.57      0.0      0.0   2650.37    2650.37       0.0
# 3339  1.0   163.79   26.21      0.0      0.0    190.00     190.00       0.0
# 3340  1.0     0.00    0.00      0.0      0.0      0.00       0.00       0.0
# 3341  1.0  3141.70    0.00      0.0      0.0   3516.20    3744.00       0.0
#
# [3342 rows x 8 columns]

# %%
#Corroborar valores nulos
valores_nulos=cuanti_clean_iqr1.isnull().sum()
valores_nulos
# Out:
# TC           0
# IMPORTE      0
# IVA          0
# RET ISR      0
# RET IVA      0
# TOTAL MX     0
# TOTAL SAT    0
# Columna1     0
# dtype: int64

# %%
#Concatenar columnas cualitativas con columnas cuantitativas
#cuali= data20['cuali']
Datos_limpios_2021= pd.concat([cuanti,cuali], axis=1)
Datos_limpios_2021
# Out:
#        TC   IMPORTE      IVA  RET ISR  RET IVA  TOTAL MX  TOTAL SAT  Columna1  \
# 0     1.0      0.00  2248.28      0.0      0.0   2248.28   16300.00  14051.72
# 1     1.0    490.00    78.40      0.0      0.0    568.40     568.40      0.00
# 2     1.0    195.00    31.20      0.0      0.0    226.20     226.20      0.00
# 3     1.0  10694.25  1711.08      0.0      0.0  12405.33   12405.33      0.00
# 4     1.0      0.00  5131.03      0.0      0.0      0.00       0.00      0.00
# ...   ...       ...      ...      ...      ...       ...        ...       ...
# 3337  1.0    129.79    20.21      0.0      0.0    150.00     150.00      0.00
# 3338  1.0   2284.80   365.57      0.0      0.0   2650.37    2650.37      0.00
# 3339  1.0    163.79    26.21      0.0      0.0    190.00     190.00      0.00
# 3340  1.0      0.00     0.00      0.0      0.0      0.00       0.00      0.00
# 3341  1.0  14889.29     0.00      0.0      0.0  14889.29   14889.29      0.00
#
# ...

# %%
#Convertir DataFrame a csv
Datos_limpios_2021.to_csv("Frame_limpio_2021.csv")

# %%
from google.colab import files

files.download("Frame_limpio_2021.csv")

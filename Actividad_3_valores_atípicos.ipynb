# %% [markdown]
# <a href="https://colab.research.google.com/github/JarlynLoza/Actividad3_valores_atipicos/blob/main/Actividad_3_valores_at%C3%ADpicos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importamos librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Cargar desde un archivo .csv sin indice
data=pd.read_csv('VentasTotalesLimpio.csv')
data
# Out:
#     Unnamed: 0 indice_tiempo  ventas_precios_corrientes  \
# 0            0    01/01/2017                    27858.9
# 1            1    01/02/2017                    25994.2
# 2            2    01/03/2017                    27780.0
# 3            3    01/04/2017                    29134.3
# 4            4    01/05/2017                    27969.0
# ..         ...           ...                        ...
# 60          60    01/01/2022                   154517.1
# 61          61    01/02/2022                   152202.6
# 62          62    01/03/2022                       16.5
# 63          63    01/04/2022                   177148.1
# 64          64    01/05/2022                   179639.2
#
#     ventas_precios_constantes  ventas_totales_canal_venta  salon_ventas  \
# 0                     27477.3                2.785887e+07  2.759173e+07
# 1                     25223.4                2.599420e+07  2.574918e+07
# 2                     26334.3                2.778001e+07  2.747223e+07
# ...

# %%
#Se corrobora valores nulos
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0                             0
# indice_tiempo                          0
# ventas_precios_corrientes              0
# ventas_precios_constantes              0
# ventas_totales_canal_venta             0
# salon_ventas                           0
# canales_on_line                        0
# ventas_totales_medio_pago              0
# efectivo                               0
# tarjetas_debito                        0
# tarjetas_credito                       0
# otros_medios                           1
# ventas_totales_grupo_articulos         0
# subtotal_ventas_alimentos_bebidas      0
# bebidas                                0
# almacen                                0
# panaderia                              0
# lacteos                                0
# carnes                                 0
# verduleria_fruteria                    0
# alimentos_preparados_rotiseria         0
# articulos_limpieza_perfumeria          0
# indumentaria_calzado_textiles_hogar    0
# ...

# %%
#Eliminar primera fila o filas innecesarias
data1= data.drop(['Unnamed: 0'],axis=1)

# %%
#Se hace una copia del DataFrame
data2=data1.copy()
data2
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %% [markdown]
# ##Columna ventas_precios_corrientes

# %%
#Realizar diagrama de caja bigote
fig1= plt.figure(figsize=(10,6))
plt.boxplot(data2["ventas_precios_corrientes"])
plt.title("Outliers de ventas_precios_corrientes")
plt.show()#Dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=data2["ventas_precios_corrientes"]

percentile25=y.quantile(0.25) #Q!
percentile75=y.quantile(0.75) #Q3
iqr= percentile75- percentile25

Limite_Superior_iqr=percentile75+1.5*iqr
Limite_Inferior_iqr=percentile25-1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 192319.35000000003
# Limite inferior permitido -59178.650000000016

# %%
#Encontramos los outliers
outliers_iqr= data2[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 42    01/07/2020                   211140.7                    50791.4
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 42                 81140696.22   76413721.76      4726974.457
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 42                81140696.22  24935747.29      22143208.63        29569224.4
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 42  ...  23393038.41  2630487.791  9592798.115  8463266.123
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 42          2712593.828                     518942.5376
#
#     articulos_limpieza_perfumeria indumentaria_calzado_textiles_hogar  \
# 42                    11217153.19                         2502616.619
#
#     electronicos_articulos_hogar        otros
# 42                   6125265.839  5935993.913
#
# [1 rows x 24 columns]

# %%
#Obtenemos datos limpios
col1=data1[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
col1
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizar diagrama de caja bigote
fig1= plt.figure(figsize=(10,6))
plt.boxplot(col1["ventas_precios_corrientes"])
plt.title("Outliers de ventas_precios_corrientes")
plt.show()#Dibujamos el diagrama

# %%
#Convertir DataFrame a csv
col1.to_csv("ventas_precios_corrientes.csv")

# %%
from google.colab import files

files.download("ventas_precios_corrientes.csv")

# %% [markdown]
# ##ventas_precios_constantes

# %%
#Realizar diagrama de caja bigote
fig= plt.figure(figsize=(10,6))
plt.boxplot(data2["ventas_precios_constantes"])
plt.title("Outliers de ventas_precios_constantes")
plt.show()#Dibujamos el diagrama

# %%
#Método aplicando desviación estándar. Encuentro los valores extremos
y=data2["ventas_precios_constantes"]
Limite_Superior=y.mean()+ 3*y.std()
Limite_Inferior=y.mean()-3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 40022.90598479884
# Limite inferior permitido 12104.484784431932

# %%
#Encontramos los outliers
outliers= data2[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 42    01/07/2020                   211140.7                    50791.4
# 60    01/01/2022                   154517.1                    45463.4
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 42                8.114070e+07  7.641372e+07      4726974.457
# 60                1.545171e+08  1.496976e+08      4819479.554
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 42               8.114070e+07  24935747.29      22143208.63       29569224.40
# 60               1.545171e+08  46962602.22      46053650.13       54048333.12
#
#     ...      almacen    panaderia       lacteos       carnes  \
# 42  ...  23393038.41  2630487.791  9.592798e+06  8463266.123
# 60  ...  37505172.62  4860317.680  1.610477e+07  17408486.73
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 42          2712593.828                    5.189425e+05
# ...

# %%
#Obtenemos datos limpios--- elimina datos atípicos
col2=data1[(y<=Limite_Superior)&(y>=Limite_Inferior)]
col2
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizamos diagrama de caja bigote
fig= plt.figure(figsize=(5,3))
plt.boxplot(col2["ventas_precios_constantes"])
plt.title("Outliers de ventas_precios_constantes")
plt.show()#Dibujamos el diagrama

# %%
#Convertir DataFrame a csv
col2.to_csv("ventas_precios_constantes.csv")

from google.colab import files

files.download("ventas_precios_constantes.csv")

# %% [markdown]
# ##Columna ventas_totales_canal_venta

# %%
#Realizar diagrama de caja bigote
fig= plt.figure(figsize=(10,6))
plt.boxplot(data2["ventas_totales_canal_venta"])
plt.title("Outliers de ventas_totales_canal_venta")
plt.show()#Dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=data2["ventas_totales_canal_venta"]

percentile25=y.quantile(0.25) #Q!
percentile75=y.quantile(0.75) #Q3
iqr= percentile75- percentile25

Limite_Superior_iqr=percentile75+1.5*iqr
Limite_Inferior_iqr=percentile25-1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 187511643.5
# Limite inferior permitido -51165850.5

# %%
#Encontramos los outliers
outliers_iqr= data2[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 42    01/07/2020                   211140.7                    50791.4
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 42                 81140696.22   76413721.76      4726974.457
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 42                81140696.22  24935747.29      22143208.63        29569224.4
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 42  ...  23393038.41  2630487.791  9592798.115  8463266.123
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 42          2712593.828                     518942.5376
#
#     articulos_limpieza_perfumeria indumentaria_calzado_textiles_hogar  \
# 42                    11217153.19                         2502616.619
#
#     electronicos_articulos_hogar        otros
# 42                   6125265.839  5935993.913
#
# [1 rows x 24 columns]

# %%
#Obtenemos datos limpios--- elimina datos atípicos
col3=data2[(y<=Limite_Superior)&(y>=Limite_Inferior)]
col3
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizar diagrama de caja bigote
fig= plt.figure(figsize=(10,6))
plt.boxplot(col3["ventas_totales_canal_venta"])
plt.title("Outliers de ventas_totales_canal_venta")
plt.show()#Dibujamos el diagrama

# %%
#Convertir DataFrame a csv
col3.to_csv("ventas_totales_canal_venta.csv")

from google.colab import files

files.download("ventas_totales_canal_venta.csv")

# %% [markdown]
# ##Columna salon_ventas

# %%
#Realizar diagrama de caja bigote
fig= plt.figure(figsize=(10,6))
plt.boxplot(data2["salon_ventas"])
plt.title("Outliers de salon_ventas")
plt.show()#Dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=data2["salon_ventas"]

percentile25=y.quantile(0.25) #Q!
percentile75=y.quantile(0.75) #Q3
iqr= percentile75- percentile25

Limite_Superior_iqr=percentile75+1.5*iqr
Limite_Inferior_iqr=percentile25-1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 170440082.58499998
# Limite inferior permitido -32001350.254999995

# %%
#Encontramos los outliers
outliers_iqr= data2[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 59    01/12/2021                   183983.2                    31595.7
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 59                 183983151.9   178866721.2      5116430.634
# 63                 177148082.8   173003799.1      4144283.743
# 64                 179639238.6   175358487.5      4280751.113
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 59                183983151.9  56640033.15      55432191.37       62999676.15
# 63                177148082.8  53189998.68      50063972.79       65357591.09
# 64                179639238.6  52738110.62      49886787.86       68070088.23
#
#     ...      almacen    panaderia      lacteos       carnes  \
# ...

# %%
#Obtenemos datos limpios--- elimina datos atípicos
col4=data2[(y<=Limite_Superior)&(y>=Limite_Inferior)]
col4
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizar diagrama de caja bigote
fig= plt.figure(figsize=(10,6))
plt.boxplot(col4["salon_ventas"])
plt.title("Outliers de salon_ventas")
plt.show()#Dibujamos el diagrama

# %%
#Convertir DataFrame a csv
col4.to_csv("salon_ventas.csv")

from google.colab import files

files.download("salon_ventas.csv")

# %% [markdown]
# ##Columna canales_on_line

# %%
#Realizar diagrama de caja bigote
fig= plt.figure(figsize=(10,6))
plt.boxplot(data2["canales_on_line"])
plt.title("Outliers de canales_on_line")
plt.show()#Dibujamos el diagrama

# %%
#Método aplicando desviación estándar. Encuentro los valores extremos
y=data1["canales_on_line"]
Limite_Superior=y.mean()+ 3*y.std()
Limite_Inferior=y.mean()-3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 7623053.091870596
# Limite inferior permitido -3467249.0753690572

# %%
#Encontramos los outliers
outliers= data2[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
#Obtenemos datos limpios--- elimina datos atípicos
col5=data2[(y<=Limite_Superior)&(y>=Limite_Inferior)]
col5
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizar diagrama de caja bigote
fig= plt.figure(figsize=(10,6))
plt.boxplot(col5["canales_on_line"])
plt.title("Outliers canales_on_line")
plt.show()#Dibujamos el diagrama

# %%
#Convertir DataFrame a csv
col5.to_csv("canales_on_line.csv")

from google.colab import files

files.download("canales_on_line.csv")

# %% [markdown]
# ##Columna efectivo

# %%
#Realizar diagrama de caja bigote
fig= plt.figure(figsize=(10,6))
plt.boxplot(data2["efectivo"])
plt.title("Outliers de efectivo")
plt.show()#Dibujamos el diagrama

# %%
#Método aplicando desviación estándar. Encuentro los valores extremos
y=data2["efectivo"]
Limite_Superior=y.mean()+ 3*y.std()
Limite_Inferior=y.mean()-3*y.std()
print("Limite superior permitido", Limite_Superior)
print("Limite inferior permitido", Limite_Inferior)
# Out:
# Limite superior permitido 61911595.63423146
# Limite inferior permitido -14342695.590508386

# %%
#Encontramos los outliers
outliers= data2[(y>Limite_Superior)|(y<Limite_Inferior)]
outliers
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
#Obtenemos datos limpios--- elimina datos atípicos
col6=data2[(y<=Limite_Superior)&(y>=Limite_Inferior)]
col6
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizar diagrama de caja bigote
fig= plt.figure(figsize=(10,6))
plt.boxplot(col6["efectivo"])
plt.title("Outliers de efectivo")
plt.show()#Dibujamos el diagrama

# %%
#Convertir DataFrame a csv
col6.to_csv("efectivo.csv")

from google.colab import files

files.download("efectivo.csv")

# %% [markdown]
# ##Columna tarjetas_debito

# %%
#Realizar diagrama de caja bigote
fig= plt.figure(figsize=(10,6))
plt.boxplot(data2["tarjetas_debito"])
plt.title("Outliers de tarjetas_debito")
plt.show()#Dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=data2["tarjetas_debito"]

percentile25=y.quantile(0.25) #Q!
percentile75=y.quantile(0.75) #Q3
iqr= percentile75- percentile25

Limite_Superior_iqr=percentile75+1.5*iqr
Limite_Inferior_iqr=percentile25-1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 50952216.5835
# Limite inferior permitido -15349161.052499998

# %%
#Encontramos los outliers
outliers_iqr= data2[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 59    01/12/2021                   183983.2                    31595.7
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 59                 183983151.9   178866721.2      5116430.634
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 59                183983151.9  56640033.15      55432191.37       62999676.15
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 59  ...  45199914.72  5859939.041  16275221.46  21265049.45
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 59          5863700.608                     1679028.685
#
#     articulos_limpieza_perfumeria indumentaria_calzado_textiles_hogar  \
# 59                    21753939.73                         4759532.634
#
#     electronicos_articulos_hogar        otros
# 59                   12669269.76  16665123.15
#
# [1 rows x 24 columns]

# %%
#Obtenemos datos limpios
col7=data2[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
col7
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizar diagrama de caja bigote
fig= plt.figure(figsize=(10,6))
plt.boxplot(col7["tarjetas_debito"])
plt.title("Outliers de tarjetas_debito")
plt.show()#Dibujamos el diagrama

# %%
#Convertir DataFrame a csv
col7.to_csv("tarjetas_debito.csv")

from google.colab import files

files.download("tarjetas_debito.csv")

# %% [markdown]
# ##Columna tarjetas_credito

# %%
#Realizar diagrama de caja bigote
fig= plt.figure(figsize=(10,6))
plt.boxplot(data2["tarjetas_credito"])
plt.title("Outliers de tarjetas_credito")
plt.show()#Dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=data2["tarjetas_credito"]

percentile25=y.quantile(0.25) #Q!
percentile75=y.quantile(0.75) #Q3
iqr= percentile75- percentile25

Limite_Superior_iqr=percentile75+1.5*iqr
Limite_Inferior_iqr=percentile25-1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 67245047.49000001
# Limite inferior permitido -22163587.950000007

# %%
#Encontramos los outliers
outliers_iqr= data2[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# 64                 179639238.6   175358487.5      4280751.113
#
#     ventas_totales_medio_pago     efectivo  tarjetas_debito  tarjetas_credito  \
# 64                179639238.6  52738110.62      49886787.86       68070088.23
#
#     ...      almacen    panaderia      lacteos       carnes  \
# 64  ...  50150351.46  6667329.665  20121124.43  22841532.85
#
#     verduleria_fruteria  alimentos_preparados_rotiseria  \
# 64           6314109.47                     1779482.857
#
#     articulos_limpieza_perfumeria indumentaria_calzado_textiles_hogar  \
# 64                    23578638.71                         5213152.564
#
#     electronicos_articulos_hogar        otros
# 64                   12039595.55  12349980.06
#
# [1 rows x 24 columns]

# %%
#Obtenemos datos limpios
col8=data2[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
col8
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizar diagrama de caja bigote
fig= plt.figure(figsize=(10,6))
plt.boxplot(col8["tarjetas_credito"])
plt.title("Outliers de tarjetas_credito")
plt.show()#Dibujamos el diagrama

# %%
#Convertir DataFrame a csv
col8.to_csv("tarjetas_credito.csv")

from google.colab import files

files.download("tarjetas_credito.csv")

# %% [markdown]
# ##Columna ventas_totales_grupo_articulos

# %%
#Realizar diagrama de caja bigote
fig= plt.figure(figsize=(10,6))
plt.boxplot(data2["ventas_totales_grupo_articulos"])
plt.title("Outliers de ventas_totales_grupo_articulos")
plt.show()#Dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=data2["ventas_totales_grupo_articulos"]

percentile25=y.quantile(0.25) #Q!
percentile75=y.quantile(0.75) #Q3
iqr= percentile75- percentile25

Limite_Superior_iqr=percentile75+1.5*iqr
Limite_Inferior_iqr=percentile25-1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 187511643.5
# Limite inferior permitido -51165850.5

# %%
#Encontramos los outliers
outliers_iqr= data2[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
#Obtenemos datos limpios
col9=data2[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
col9
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizar diagrama de caja bigote
fig= plt.figure(figsize=(10,6))
plt.boxplot(col9["ventas_totales_grupo_articulos"])
plt.title("Outliers de ventas_totales_grupo_articulos")
plt.show()#Dibujamos el diagrama

# %%
#Convertir DataFrame a csv
col9.to_csv("ventas_totales_grupo_articulos.csv")

from google.colab import files

files.download("ventas_totales_grupo_articulos.csv")

# %% [markdown]
# ##Columna subtotal_ventas_alimentos_bebidas

# %%
#Realizar diagrama de caja bigote
fig= plt.figure(figsize=(10,6))
plt.boxplot(data2["subtotal_ventas_alimentos_bebidas"])
plt.title("Outliers de subtotal_ventas_alimentos_bebidas")
plt.show()#Dibujamos el diagrama

# %%
#Método aplicando Cuartiles. Encuentro cuartiles 0.25 y 0.75
y=data2["subtotal_ventas_alimentos_bebidas"]

percentile25=y.quantile(0.25) #Q!
percentile75=y.quantile(0.75) #Q3
iqr= percentile75- percentile25

Limite_Superior_iqr=percentile75+1.5*iqr
Limite_Inferior_iqr=percentile25-1.5*iqr
print("Limite superior permitido", Limite_Superior_iqr)
print("Limite inferior permitido", Limite_Inferior_iqr)
# Out:
# Limite superior permitido 135934765.575
# Limite inferior permitido -47434646.705000006

# %%
#Encontramos los outliers
outliers_iqr= data2[(y>Limite_Superior_iqr)|(y<Limite_Inferior_iqr)]
outliers_iqr
# Out:
# Empty DataFrame
# Columns: [indice_tiempo, ventas_precios_corrientes, ventas_precios_constantes, ventas_totales_canal_venta, salon_ventas, canales_on_line, ventas_totales_medio_pago, efectivo, tarjetas_debito, tarjetas_credito, otros_medios, ventas_totales_grupo_articulos, subtotal_ventas_alimentos_bebidas, bebidas, almacen, panaderia, lacteos, carnes, verduleria_fruteria, alimentos_preparados_rotiseria, articulos_limpieza_perfumeria, indumentaria_calzado_textiles_hogar, electronicos_articulos_hogar, otros]
# Index: []
#
# [0 rows x 24 columns]

# %%
#Obtenemos datos limpios
col10=data2[(y<=Limite_Superior_iqr)&(y>=Limite_Inferior_iqr)]
col10
# Out:
#    indice_tiempo  ventas_precios_corrientes  ventas_precios_constantes  \
# 0     01/01/2017                    27858.9                    27477.3
# 1     01/02/2017                    25994.2                    25223.4
# 2     01/03/2017                    27780.0                    26334.3
# 3     01/04/2017                    29134.3                    27045.9
# 4     01/05/2017                    27969.0                    25631.9
# ..           ...                        ...                        ...
# 60    01/01/2022                   154517.1                    45463.4
# 61    01/02/2022                   152202.6                    23802.1
# 62    01/03/2022                       16.5                    24612.4
# 63    01/04/2022                   177148.1                    24140.5
# 64    01/05/2022                   179639.2                    23234.2
#
#     ventas_totales_canal_venta  salon_ventas  canales_on_line  \
# ...

# %%
#Realizar diagrama de caja bigote
fig= plt.figure(figsize=(10,6))
plt.boxplot(col10["subtotal_ventas_alimentos_bebidas"])
plt.title("Outliers de subtotal_ventas_alimentos_bebidas")
plt.show()#Dibujamos el diagrama

# %%
#Convertir DataFrame a csv
col10.to_csv("subtotal_ventas_alimentos_bebidas.csv")

from google.colab import files

files.download("subtotal_ventas_alimentos_bebidas.csv")
